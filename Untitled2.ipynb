# %% [markdown]
# <a href="https://colab.research.google.com/github/kohei-nakakubo/ai-coaching-app-new/blob/coaching-ai-app/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 必要なライブラリをインストール（Google Colab等で実行する場合）
# !pip install python-pptx

from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN

def create_presentation():
    # プレゼンテーションの作成
    prs = Presentation()

    # スライドの内容定義
    slides_data = [
        {
            "layout": 0, # Title Slide
            "title": "9割の歯科医院が年商1億円を達成できない\n理由と解決策",
            "subtitle": "〜「プレイヤー」から「経営者」へ〜\n\n講師: 化粧 由美子 先生\n(泉崎ファミリー歯科 院長 / MBAホルダー)",
            "notes": "背景指示: 清潔感のある歯科医院のイメージ写真。中央に大きくタイトルを配置。"
        },
        {
            "layout": 1, # Title and Content
            "title": "1. はじめに：現状の課題",
            "content": [
                "9割の医院が「年商1億円」の壁を越えられない",
                "■ 現状",
                "  - 年商1億円達成医院は全体のわずか 約10%",
                "■ 課題",
                "  - 多くの院長が「感覚」で経営している",
                "  - 患者数にばらつきがある / 忙しいのに利益が残らない",
                "■ 根本原因",
                "  - 歯科医師は医療技術の専門家だが、「経営」を学ぶ機会がなかった"
            ],
            "notes": "映像指示: [0:44] 円グラフで「達成(10%)」と「未達成(90%)」を対比表示"
        },
        {
            "layout": 1,
            "title": "2. 成長を阻む「3つの原因」",
            "content": [
                "経営が伸び悩む医院に共通する、3つのボトルネック",
                "",
                "1. 🧲 集患を仕組み化できていない",
                "   - 「運任せ」の集患になっている",
                "2. 💰 自費率の低さ",
                "   - 保険診療中心で、提案力に課題がある",
                "3. 📊 経営を数字で把握していない",
                "   - どんぶり勘定で、改善ポイントが見えない"
            ],
            "notes": "映像指示: [4:26] 3つのポイントをアイコン付き（磁石、硬貨、グラフ）で並列表示"
        },
        {
            "layout": 1,
            "title": "原因①：集患が「運任せ」になっている",
            "content": [
                "口コミや立地頼みの経営は、環境変化に弱い",
                "",
                "■ 仕組みがない医院の特徴",
                "  - HPが簡素・更新されていない / Web予約への導線が悪い",
                "  - 症例写真が見られない",
                "■ 典型的な失敗パターン",
                "  - 開業〜7年は自然増 → 競合出現で右肩下がりへ",
                "  - 15-20年目の設備投資時期に資金難に陥る"
            ],
            "notes": "映像指示: [6:48] 開業7年目をピークに患者数が減少するグラフイメージ"
        },
        {
            "layout": 1,
            "title": "原因②＆③：収益構造と管理の甘さ",
            "content": [
                "■ 原因②：自費率の低さ",
                "  - 薄利多売の限界: 保険診療中心では売上に天井がある",
                "  - 一貫性の欠如: スタッフ、ドクターの説明がバラバラで患者が混乱",
                "",
                "■ 原因③：数字管理の欠如",
                "  - 感覚経営: 「今月はなんとなく忙しい」で終わらせている",
                "  - 売上、利益、LTV（顧客生涯価値）を判断材料にしていない"
            ],
            "notes": "映像指示: [8:19] バラバラな説明をするスタッフと混乱する患者の図解"
        },
        {
            "layout": 1,
            "title": "解決策①：集患の自動化 (MEO対策)",
            "content": [
                "「地域名 + 歯医者」検索での上位表示が最重要",
                "",
                "■ Googleビジネスプロフィールの充実",
                "  - 診療時間、商品（矯正・セラミック等）を500文字程度で詳述",
                "■ アクティブな発信",
                "  - 週1回の投稿（院内の様子、季節のイベント）",
                "■ 口コミ対策",
                "  - 院内にQRコードを設置し、書き込みやすい環境を作る"
            ],
            "notes": "映像指示: [11:02] スマホ画面でGoogleマップ検索結果（上位表示）のイメージ"
        },
        {
            "layout": 1,
            "title": "解決策①：認知から予約への「勝利の方程式」",
            "content": [
                "各メディアの役割を明確にし、導線をつなぐ",
                "",
                "1. 認知 (YouTube)",
                "   - 情報をストックし、広範囲に認知させる",
                "2. 教育・信頼 (Instagram)",
                "   - 症例写真で技術力を、ストーリーズで人柄を伝える",
                "3. 確認 (Googleマップ)",
                "   - 口コミで評判を確認する",
                "4. 行動 (HP/LP)",
                "   - 最終的な受け皿として、Web予約へ誘導する"
            ],
            "notes": "映像指示: [14:47] 認知→信頼→行動のフローチャート図"
        },
        {
            "layout": 1,
            "title": "解決策②：自費率向上のための体制",
            "content": [
                "誰が担当しても同じ成果が出せる「仕組み」を作る",
                "",
                "■ 初診カウンセリングの導入",
                "  - ドクターの前にスタッフがヒアリング",
                "  - 信頼関係構築で成約率が2〜3倍に",
                "■ 院内情報の統一",
                "  - ロールプレイングで説明スキルを標準化",
                "■ ブランディング",
                "  - 資料のフォント・色味を統一し、高級感と安心感を演出"
            ],
            "notes": "映像指示: [16:49] カウンセリング風景と成約率UPのアイコン"
        },
        {
            "layout": 1,
            "title": "解決策③：LTV重視の数値管理",
            "content": [
                "経営安定の鍵は「リピート」にあり",
                "",
                "■ 見るべき3つの数字",
                "  1. 売上",
                "  2. 利益",
                "  3. LTV (Life Time Value): 患者1人あたりの生涯収益",
                "■ LTVの簡易チェック",
                "  - 初診患者がメンテナンス（SPT）に移行した割合を確認",
                "■ スタッフ共有",
                "  - 数字をチームで共有し、経営への参加意識を高める"
            ],
            "notes": "映像指示: [21:53] LTVの概念図（初診→治療→メンテナンス継続）"
        },
        {
            "layout": 1,
            "title": "まとめ：年商1億円へのロードマップ",
            "content": [
                "売上の壁を突破するのは「努力量」ではなく「経営意識」",
                "",
                "1. 集患の自動化: MEOとWeb導線を整備する",
                "2. 高収益体質へ: カウンセリングで自費率を高める",
                "3. データ経営: LTVを指標に改善を繰り返す",
                "",
                "💡 Next Step:",
                "まずは「プレイヤー」視点から一歩引き、現場を回す仕組み作りから始めましょう"
            ],
            "notes": "映像指示: [26:16] 3つのアイコンにチェックマーク。公式LINE誘導など"
        }
    ]

    # スライド生成ループ
    for slide_data in slides_data:
        layout_index = slide_data["layout"]
        slide = prs.slides.add_slide(prs.slide_layouts[layout_index])

        # タイトル設定
        title = slide.shapes.title
        title.text = slide_data["title"]

        # コンテンツ（サブタイトルまたは本文）設定
        if layout_index == 0: # Title Slide
            subtitle = slide.placeholders[1]
            subtitle.text = slide_data["subtitle"]
        else: # Content Slide
            body = slide.placeholders[1]
            tf = body.text_frame
            tf.text = slide_data["content"][0] # 1行目

            for line in slide_data["content"][1:]:
                p = tf.add_paragraph()
                p.text = line
                if line.strip().startswith("-") or line.strip().startswith("■"):
                    p.level = 1
                elif line.strip().startswith("1.") or line.strip().startswith("2."):
                    p.level = 0
                else:
                    p.level = 0

        # ノート設定（ビジュアル指示）
        if "notes" in slide_data:
            notes_slide = slide.notes_slide
            text_frame = notes_slide.notes_text_frame
            text_frame.text = slide_data["notes"]

    # ファイル保存
    file_name = "Dental_Clinic_Strategy.pptx"
    prs.save(file_name)
    print(f"'{file_name}' が作成されました。ダウンロードしてください。")

if __name__ == "__main__":
    create_presentation()
# Out:
# ...
# 'Dental_Clinic_Strategy.pptx' が作成されました。ダウンロードしてください。
